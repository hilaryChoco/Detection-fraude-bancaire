# %% [markdown]
# # I- EDA & nettoyage

# %% [markdown]
# ## Prise en main du dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns", None)

df = pd.read_csv("../data/raw/creditcard.csv")

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %% [markdown]
# - **Dimensions** : 284 807 transactions × 31 colonnes
# - **Colonnes** : `Time`, `V1`–`V28` (composantes PCA anonymisées), `Amount`, `Class`
# - **Types** : entièrement numériques
# - **Valeurs manquantes** : aucune
# - **Doublons** : 1081 lignes (~0,38 %)

# %% [markdown]
# ## Déséquilibre des classes

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df['Class'].value_counts(normalize=True)
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %%
ax = sns.countplot(data=df, x='Class')
ax.set_yscale('log')
ax.set_title("Répartition des classes — 0,17 % de fraudes (échelle log)")
# Out:
# Text(0.5, 1.0, 'Répartition des classes — 0,17 % de fraudes (échelle log)')

# %% [markdown]
# ## Statistiques descriptives

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %%
df['Amount'].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
ax = sns.histplot(data=df, x='Amount')
ax.set_xscale('log')

# %% [markdown]
# ## Analyse comparative par classe

# %%
df.groupby('Class')['Amount'].describe()
# Out:
#           count        mean         std  min   25%    50%     75%       max
# Class
# 0      284315.0   88.291022  250.105092  0.0  5.65  22.00   77.05  25691.16
# 1         492.0  122.211321  256.683288  0.0  1.00   9.25  105.89   2125.87

# %%
sns.boxplot(data=df, x='Class', y='Amount', showfliers=False)
# Out:
# <Axes: xlabel='Class', ylabel='Amount'>

# %%
sns.boxplot(data=df, x='Class', y='V14')
# Out:
# <Axes: xlabel='Class', ylabel='V14'>

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9       V10       V11       V12  \
# Class
# 0      0.002419  0.009637 -0.000987  0.004467  0.009824 -0.006576  0.010832
# 1     -1.397737 -5.568731  0.570636 -2.581123 -5.676883  3.800173 -6.259393
#
#             V13       V14       V15       V16       V17       V18       V19  \
# Class
# 0      0.000189  0.012064  0.000161  0.007164  0.011535  0.003887 -0.001178
# 1     -0.109334 -6.971723 -0.092929 -4.139946 -6.665836 -2.246308  0.680659
#
#             V20       V21       V22       V23       V24       V25       V26  \
# Class
# 0     -0.000644 -0.001235 -0.000024  0.000070  0.000182 -0.000072 -0.000089
# 1      0.372319  0.713588  0.014049 -0.040308 -0.105130  0.041449  0.051648
#
# ...

# %%
df.groupby('Class').mean().loc[1].abs().sort_values(ascending=False)
# Out:
# Time      80746.806911
# Amount      122.211321
# V3            7.033281
# V14           6.971723
# V17           6.665836
# V12           6.259393
# V10           5.676883
# V7            5.568731
# V1            4.771948
# V4            4.542029
# V16           4.139946
# V11           3.800173
# V2            3.623778
# V5            3.151225
# V9            2.581123
# V18           2.246308
# V6            1.397737
# V21           0.713588
# V19           0.680659
# V8            0.570636
# V20           0.372319
# V27           0.170575
# V13           0.109334
# V24           0.105130
# V15           0.092929
# V28           0.075667
# V26           0.051648
# V25           0.041449
# V23           0.040308
# V22           0.014049
# Name: 1, dtype: float64

# %% [markdown]
# ## Corrélations

# %%
corr = df.corr()

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %% [markdown]
# ## Nettoyage raisonné

# %%
doublons = df[df.duplicated()]

# %%
doublons['Class'].value_counts()
# Out:
# Class
# 0    1062
# 1      19
# Name: count, dtype: int64

# %%
df_clean = df.drop_duplicates()

# %%
df_clean.shape
# Out:
# (283726, 31)

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Doublons.** Le dataset comportait 1081 lignes strictement identiques.
# Vérification menée avant toute suppression : s'agit-il de vrais doublons
# techniques (même transaction enregistrée deux fois) ou de coïncidences
# (deux transactions réelles distinctes) ? Conclusion : des **doublons
# techniques**. Il est en effet quasi impossible que deux clients différents
# partagent exactement les mêmes composantes V1–V28 (issues d'un PCA, en
# décimales au millionième près). Répartition : 1062 légitimes, 19 frauduleux
# — ces 19 étant des copies de fraudes déjà présentes, aucun cas unique de
# fraude n'est perdu. **Décision : suppression.** Résultat : 283 726 lignes.
#
# **Valeurs extrêmes (outliers).** Décision : **conservation**. En détection
# de fraude, l'anomalie n'est pas du bruit à nettoyer mais le signal lui-même :
# les fraudes se manifestent précisément comme des valeurs extrêmes (vu au
# boxplot de V14). Supprimer les outliers reviendrait à supprimer les fraudes
# qu'on cherche à détecter. Le nettoyage dépend de l'objectif : ici, ces cas
# rares sont une information capitale.

# %% [markdown]
# # II- Préparation à la modélisation

# %% [markdown]
# ## Séparation train/test (stratifiée)

# %%
X = df_clean.drop('Class', axis=1)
y = df_clean['Class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    stratify=y,
    random_state=42
)

# %%
y_train.value_counts(normalize=True)
# Out:
# Class
# 0    0.998333
# 1    0.001667
# Name: proportion, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# Class
# 0    0.998332
# 1    0.001668
# Name: proportion, dtype: float64

# %% [markdown]
# ## Mise à l'échelle des variables

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

# %% [markdown]
# ## Stratégie face au déséquilibre
#
# Trois approches envisagées : sous-échantillonnage, sur-échantillonnage (SMOTE),
# pondération des classes.
#
# **Décision : pondération des classes** (`class_weight='balanced'`), appliquée
# au modèle.
#
# Justification :
# - Sous-échantillonnage écarté : jeter l'essentiel des légitimes appauvrirait
#   la diversité du « normal » → risque de faux positifs sur des transactions
#   légitimes atypiques.
# - Sur-échantillonnage (SMOTE) écarté pour un premier jet : génère des fraudes
#   synthétiques au réalisme incertain.
# - Pondération retenue : ne jette ni n'invente aucune donnée, force le modèle à
#   pénaliser lourdement les fraudes manquées. Baseline simple et réversible.

# %% [markdown]
# # III- Modélisation & évaluation

# %% [markdown]
# ## Modèle de référence (baseline)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(class_weight='balanced', max_iter=1000)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
y_pred = model.predict(X_test_scaled)

# %% [markdown]
# ## Métriques adaptées

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred)
# Out:
# array([[82709,  2267],
#        [   16,   126]])

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     84976
#            1       0.05      0.89      0.10       142
#
#     accuracy                           0.97     85118
#    macro avg       0.53      0.93      0.54     85118
# weighted avg       1.00      0.97      0.98     85118

# %% [markdown]
# Baseline évalué avec les bonnes métriques (matrice de confusion, précision/rappel/F1) ; accuracy explicitement écartée. Référence posée : recall 0,89 - precision 0,05 - F1 0,10 sur la fraude. Ensuite une forêt aléatoire, qu'on comparera à ces chiffres.

# %% [markdown]
# ## Modèles avancés + comparaison (+ validation croisée)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)
rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_jobs=-1, random_state=42)

# %%
y_pred_rf = rf.predict(X_test_scaled)

from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred_rf)
# Out:
# array([[84969,     7],
#        [   37,   105]])

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84976
#            1       0.94      0.74      0.83       142
#
#     accuracy                           1.00     85118
#    macro avg       0.97      0.87      0.91     85118
# weighted avg       1.00      1.00      1.00     85118

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

# probabilités de la classe "fraude"
proba_train = rf.predict_proba(X_train_scaled)[:, 1]
proba_test  = rf.predict_proba(X_test_scaled)[:, 1]

# calcul des deux courbes précision-rappel
prec_train, rec_train, _ = precision_recall_curve(y_train, proba_train)
prec_test,  rec_test,  _ = precision_recall_curve(y_test,  proba_test)

# tracé sur une même figure
plt.figure(figsize=(8, 6))
plt.plot(rec_train, prec_train, label="Entraînement (train)")
plt.plot(rec_test,  prec_test,  label="Test")
plt.xlabel("Rappel (recall)")
plt.ylabel("Précision (precision)")
plt.title("Courbe précision-rappel — forêt aléatoire")
plt.legend()
plt.grid(True)
plt.savefig("../reports/courbe_precision_rappel.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Réglage du seuil

# %%
prec_test, rec_test, seuils_test = precision_recall_curve(y_test, proba_test)

# %%
import numpy as np

cible = 0.82

# rec_test a une valeur de plus que seuils_test → on aligne en retirant le dernier point
rec_aligne = rec_test[:-1]
prec_aligne = prec_test[:-1]

# index du point dont le rappel est le plus proche de la cible
i = np.argmin(np.abs(rec_aligne - cible))

seuil_choisi = seuils_test[i]
print(f"Seuil choisi : {seuil_choisi:.3f}")
print(f"→ rappel = {rec_aligne[i]:.3f}, précision = {prec_aligne[i]:.3f}")
# Out:
# Seuil choisi : 0.060
# → rappel = 0.824, précision = 0.448

# %%
import numpy as np

# F1 en chaque point (on réutilise les tableaux alignés)
f1_scores = 2 * (prec_aligne * rec_aligne) / (prec_aligne + rec_aligne + 1e-9)

j = np.argmax(f1_scores)   # position du meilleur F1
seuil_optimal = seuils_test[j]

print(f"Seuil optimal (max F1) : {seuil_optimal:.3f}")
print(f"→ rappel = {rec_aligne[j]:.3f}, précision = {prec_aligne[j]:.3f}, F1 = {f1_scores[j]:.3f}")
# Out:
# Seuil optimal (max F1) : 0.440
# → rappel = 0.754, précision = 0.939, F1 = 0.836

# %%
from sklearn.metrics import confusion_matrix, classification_report

seuil = 0.44   # ou essaie 0.20 pour voir l'effet "plus de rappel"
y_pred_seuil = (proba_test >= seuil).astype(int)

print(confusion_matrix(y_test, y_pred_seuil))
print(classification_report(y_test, y_pred_seuil))
# Out:
# [[84969     7]
#  [   35   107]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84976
#            1       0.94      0.75      0.84       142
#
#     accuracy                           1.00     85118
#    macro avg       0.97      0.88      0.92     85118
# weighted avg       1.00      1.00      1.00     85118

# %%
from sklearn.metrics import confusion_matrix, classification_report

seuil = 0.20   # ou essaie 0.20 pour voir l'effet "plus de rappel"
y_pred_seuil = (proba_test >= seuil).astype(int)

print(confusion_matrix(y_test, y_pred_seuil))
print(classification_report(y_test, y_pred_seuil))
# Out:
# [[84956    20]
#  [   27   115]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84976
#            1       0.85      0.81      0.83       142
#
#     accuracy                           1.00     85118
#    macro avg       0.93      0.90      0.92     85118
# weighted avg       1.00      1.00      1.00     85118

# %% [markdown]
# ## Validation croisée

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier

# 5 paquets stratifiés (proportion de fraude préservée dans chacun)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# on ré-instancie le modèle (mêmes réglages qu'au Ticket-12)
rf_cv = RandomForestClassifier(
    n_estimators=100, class_weight='balanced',
    random_state=42, n_jobs=-1
)

# validation croisée, évaluée sur le F1 de la classe fraude
scores = cross_val_score(rf_cv, X_train_scaled, y_train,
                         cv=cv, scoring='f1', n_jobs=-1)

print("F1 par paquet :", scores.round(3))
print(f"F1 moyen : {scores.mean():.3f}  (±{scores.std():.3f})")
# Out:
# F1 par paquet : [0.813 0.864 0.826 0.885 0.867]
# F1 moyen : 0.851  (±0.027)

# %% [markdown]
# # IV - Synthèse

# %% [markdown]
# **Problème.** Détecter les transactions frauduleuses par carte bancaire à partir
# d'un jeu de ~285 000 transactions. Difficulté centrale : un déséquilibre extrême
# — 0,17 % de fraudes pour 99,83 % de transactions légitimes. Ce déséquilibre a
# gouverné toutes les décisions du projet, du choix des métriques à la stratégie
# d'entraînement.
#
# **Exploration.** L'analyse a montré que le montant (`Amount`) ne suffit pas à
# distinguer une fraude : les distributions des deux classes se recouvrent trop.
# Le signal se concentre dans une poignée de composantes anonymisées (V14, V17,
# V12, V10…), où fraude et légitime se séparent nettement. Décision de nettoyage
# clé : conserver les valeurs extrêmes plutôt que les supprimer — en détection de
# fraude, l'anomalie n'est pas du bruit, c'est le signal recherché. Seuls les 1081
# doublons techniques ont été retirés, après vérification qu'aucun cas unique de
# fraude n'était perdu.
#
# **Préparation.** Séparation train/test stratifiée pour préserver la proportion de
# fraudes des deux côtés (essentiel vu leur rareté). Mise à l'échelle des variables
# calibrée sur le train uniquement, puis appliquée au test — afin d'éviter toute
# fuite de données. Face au déséquilibre, choix de la pondération des classes
# (`class_weight='balanced'`), qui ne jette ni n'invente aucune donnée.
#
# **Modèles et résultat.** Comparaison d'un baseline (régression logistique) et
# d'une forêt aléatoire. Le baseline capturait 89 % des fraudes mais avec 5 % de
# précision seulement (2267 fausses alertes) — trop bruyant. La forêt aléatoire l'a
# nettement emporté : F1 de 0,83 sur le test, confirmé à 0,85 ± 0,03 par validation
# croisée stratifiée (résultat stable, non dû au hasard du découpage). Le réglage du
# seuil de décision a ensuite permis de piloter volontairement le compromis
# précision/rappel selon la priorité métier : au seuil retenu (0,20), le modèle
# attrape 115 des 142 fraudes avec seulement 20 fausses alertes.
#
# **Limites et suites.** Le modèle utilise les réglages par défaut : l'optimisation
# des hyperparamètres (via GridSearchCV, ou Optuna pour une recherche plus avancée)
# est la prochaine amélioration identifiée. Un test sur des données plus récentes
# et la connaissance des coûts métier réels (montant moyen d'une fraude, coût de
# traitement d'une alerte) permettraient d'affiner le choix du seuil.
